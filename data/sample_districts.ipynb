# %%
import os
import geopandas as gpd
from shapely.geometry import Point

# %%
try:
    gdf_districts = gpd.read_file("limites_adm_geoportal_distrito_municipal_v2.geojson")
    gdf_vulnerability = gpd.read_file("geoportal_setor_censitario_vuln.geojson")
except Exception as e:
    print(f"Error loading files: {e}")
    exit()

gdf_districts_wgs84 = gdf_districts.to_crs(epsg=4326)
gdf_vulnerability_wgs84 = gdf_vulnerability.to_crs(epsg=4326)

districts_subset = gdf_districts_wgs84[['nm_distrito_municipal', 'geometry']]

merged_gdf = gpd.sjoin(gdf_vulnerability_wgs84, districts_subset, how="left", predicate="within")
merged_gdf = merged_gdf.rename(columns={'nm_distrito_municipal': 'distrito'})

# Drop the extra index column created by the join
merged_gdf = merged_gdf.drop(columns=['index_right'])

# Keep only the rows where the 'distrito' column is not NaN
gdf_filtered = merged_gdf.dropna(subset=['distrito'])

print("\nSuccessfully added the 'distrito' column and filtered out non-matching rows.")
print("\nColumns of the final GeoDataFrame:")
print(gdf_filtered.columns)

print("\n\nPreview of the first 5 rows of the final data:")
print(gdf_filtered[['cd_identificador', 'qt_populacao', 'distrito', 'geometry']].head())

output_filename = "vulnerability_with_district_name_filtered.geojson"
try:
    gdf_filtered.to_file(output_filename, driver='GeoJSON')
    print(f"\n\nSuccessfully saved the filtered result to '{output_filename}'")
except Exception as e:
    print(f"\n\nAn error occurred while saving the file: {e}")
# Out:
# Successfully added the 'distrito' column and filtered out non-matching rows.
#
# Columns of the final GeoDataFrame:
# Index(['id', 'cd_identificador', 'cd_identificador_domicilio_censitario',
#        'cd_identificador_densidade_demografica',
#        'cd_identificador_vulnerabilidade_social',
#        'cd_identificador_georreferenciamento', 'qt_area_setor_censitario',
#        'cd_original_setor_censitario', 'an_censo_demografico',
#        'cd_setor_censitario_domicilio', 'qt_domicilio', 'an_censo_domicilio',
#        'cd_setor_censitario_vulnerabilidade',
#        'cd_indice_vulnerabilidade_social', 'an_vulnerabilidade_social',
#        'cd_setor_censitario_densidade', 'qt_populacao', 'qt_area_hectare',
#        'qt_habitante_hectare', 'an_densidade_demografica', 'geometry',
#        'distrito'],
#       dtype='object')
#
#
# Preview of the first 5 rows of the final data:
#   cd_identificador  qt_populacao        distrito  \
# 2            32355         573.0  RAPOSO TAVARES
# 3            32356         156.0  RAPOSO TAVARES
# 5            24961         306.0      PONTE RASA
# 6            24962         391.0      PONTE RASA
# 7            24963         432.0      PONTE RASA
#
#                                             geometry
# 2  POLYGON ((-46.78918 -23.59919, -46.78955 -23.5...
# 3  POLYGON ((-46.78955 -23.59906, -46.78969 -23.5...
# 5  POLYGON ((-46.50763 -23.51855, -46.50827 -23.5...
# 6  POLYGON ((-46.50789 -23.51704, -46.50764 -23.5...
# 7  POLYGON ((-46.50624 -23.51439, -46.50615 -23.5...
#
#
# Successfully saved the filtered result to 'vulnerability_with_district_name_filtered.geojson'

# %%
gdf_filtered.head(5)
# Out:
#                        id cd_identificador  \
# 2  setor_censitario.32355            32355
# 3  setor_censitario.32356            32356
# 5  setor_censitario.24961            24961
# 6  setor_censitario.24962            24962
# 7  setor_censitario.24963            24963
#
#    cd_identificador_domicilio_censitario  \
# 2                                12415.0
# 3                                12414.0
# 5                                12197.0
# 6                                12198.0
# 7                                12179.0
#
#    cd_identificador_densidade_demografica  \
# 2                                    6171
# 3                                    6172
# 5                                    6265
# 6                                    6266
# 7                                    6267
#
#    cd_identificador_vulnerabilidade_social  \
# 2                                  12415.0
# 3                                  12414.0
# 5                                  12197.0
# 6                                  12198.0
# 7                                  12179.0
#
#   cd_identificador_georreferenciamento  qt_area_setor_censitario  \
# 2                                 None                 1004.4755
# 3                                 None                 2260.1768
# 5                                 None                29553.1866
# 6                                 None                50021.4491
# 7                                 None                40616.2685
#
#   cd_original_setor_censitario  an_censo_demografico  \
# 2              355030865000149                  2010
# 3              355030865000148                  2010
# 5              355030864000088                  2010
# 6              355030864000089                  2010
# 7              355030864000070                  2010
#
#   cd_setor_censitario_domicilio  ...  cd_setor_censitario_vulnerabilidade  \
# 2               355030865000149  ...                      355030865000149
# 3               355030865000148  ...                      355030865000148
# 5               355030864000088  ...                      355030864000088
# 6               355030864000089  ...                      355030864000089
# 7               355030864000070  ...                      355030864000070
#
#    cd_indice_vulnerabilidade_social an_vulnerabilidade_social  \
# 2                               4.0                    2010.0
# 3                               0.0                    2010.0
# 5                               2.0                    2010.0
# 6                               2.0                    2010.0
# 7                               2.0                    2010.0
#
#    cd_setor_censitario_densidade  qt_populacao qt_area_hectare  \
# 2                355030865000149         573.0        0.100683
# 3                355030865000148         156.0        0.226534
# 5                355030864000088         306.0        2.962862
# 6                355030864000089         391.0        5.014908
# 7                355030864000070         432.0        4.071997
#
#    qt_habitante_hectare  an_densidade_demografica  \
# 2           5691.134318                      2010
# 3            688.637730                      2010
# 5            103.278515                      2010
# 6             77.967529                      2010
# 7            106.090455                      2010
#
#                                             geometry        distrito
# 2  POLYGON ((-46.78918 -23.59919, -46.78955 -23.5...  RAPOSO TAVARES
# 3  POLYGON ((-46.78955 -23.59906, -46.78969 -23.5...  RAPOSO TAVARES
# 5  POLYGON ((-46.50763 -23.51855, -46.50827 -23.5...      PONTE RASA
# 6  POLYGON ((-46.50789 -23.51704, -46.50764 -23.5...      PONTE RASA
# 7  POLYGON ((-46.50624 -23.51439, -46.50615 -23.5...      PONTE RASA
#
# [5 rows x 22 columns]

# %%
gdf_filtered['distrito'].value_counts()
# Out:
# distrito
# GRAJAU             655
# JABAQUARA          370
# CAPAO REDONDO      367
# JARDIM ANGELA      361
# JARDIM SAO LUIS    359
#                   ...
# CAMBUCI             36
# BOM RETIRO          34
# BARRA FUNDA         21
# JAGUARA             18
# PARI                17
# Name: count, Length: 96, dtype: int64

# %%
def get_district_from_coords(longitude, latitude, gdf):
    """
    Finds the district in São Paulo that contains the given coordinates.

    Args:
        longitude (float): The longitude of the point.
        latitude (float): The latitude of the point.
        gdf (GeoDataFrame): A GeoDataFrame containing the district geometries.

    Returns:
        str: The name of the district containing the point, or a message if not found.
    """
    if gdf.empty:
        return 

    point = Point(longitude, latitude)

    for index, row in gdf.iterrows():
        if row['geometry'].contains(point):
            return row

# %%
example_latitude, example_longitude = -23.53028637943643, -46.612411709376424

district = get_district_from_coords(example_longitude, example_latitude, gdf_filtered)

if district is not None:
    print(f"The point {example_longitude}, {example_latitude} is: {district['distrito']} - vuln: {district['cd_indice_vulnerabilidade_social']}")
# Out:
# The point -46.612411709376424, -23.53028637943643 is: PARI - vuln: 2.0

# %% [markdown]
# ### How many samples per district?

# %%
gdf_filtered['distrito'].value_counts()
# Out:
# distrito
# GRAJAU             655
# JABAQUARA          370
# CAPAO REDONDO      367
# JARDIM ANGELA      361
# JARDIM SAO LUIS    359
#                   ...
# CAMBUCI             36
# BOM RETIRO          34
# BARRA FUNDA         21
# JAGUARA             18
# PARI                17
# Name: count, Length: 96, dtype: int64

# %%
(gdf_filtered['distrito'].value_counts() > 100).sum()
# Out:
# np.int64(80)

# %% [markdown]
# ### Stratified Sampling

# %%
output_dir = "samples"
os.makedirs(output_dir, exist_ok=True)
print(f"Created directory: '{output_dir}'")

# Get the unique distrito names
distritos = gdf_filtered['distrito'].unique()

total_samples_collected = 0

for distrito_name in distritos:
    print(f"\nProcessing distrito: {distrito_name}")

    # Filter the GeoDataFrame for the current distrito
    distrito_gdf = gdf_filtered[gdf_filtered['distrito'] == distrito_name]

    # Determine the number of samples to take
    n_samples = min(100, len(distrito_gdf))

    # Perform the random sampling
    sampled_gdf = distrito_gdf.sample(n=n_samples, random_state=42) 

    print(f"  - Total rows: {len(distrito_gdf)}")
    print(f"  - Sampled rows: {len(sampled_gdf)}")
    total_samples_collected += len(sampled_gdf)

    # Define the output path for the sample
    sample_output_filename = f"{output_dir}/{distrito_name}.geojson"

    # Save the sampled GeoDataFrame to a new GeoJSON file
    try:
        sampled_gdf.to_file(sample_output_filename, driver='GeoJSON')
        print(f"  - Successfully saved sample to '{sample_output_filename}'")
    except Exception as e:
        print(f"  - An error occurred while saving the sample file: {e}")

print("\n--- Random sampling process completed ---")
print(f'Total samples = {total_samples_collected}')
# Out:
# Created directory: 'samples'
#
# Processing distrito: RAPOSO TAVARES
#   - Total rows: 194
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/RAPOSO TAVARES.geojson'
#
# Processing distrito: PONTE RASA
#   - Total rows: 142
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PONTE RASA.geojson'
#
# Processing distrito: JARDIM ANGELA
#   - Total rows: 361
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JARDIM ANGELA.geojson'
#
# Processing distrito: ERMELINO MATARAZZO
#   - Total rows: 156
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ERMELINO MATARAZZO.geojson'
#
# Processing distrito: VILA JACUI
#   - Total rows: 208
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA JACUI.geojson'
#
# Processing distrito: CIDADE TIRADENTES
#   - Total rows: 302
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CIDADE TIRADENTES.geojson'
#
# Processing distrito: ITAQUERA
#   - Total rows: 235
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ITAQUERA.geojson'
#
# Processing distrito: JACANA
#   - Total rows: 121
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JACANA.geojson'
#
# Processing distrito: VILA MATILDE
#   - Total rows: 119
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA MATILDE.geojson'
#
# Processing distrito: ARTUR ALVIM
#   - Total rows: 121
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ARTUR ALVIM.geojson'
#
# Processing distrito: CIDADE LIDER
#   - Total rows: 145
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CIDADE LIDER.geojson'
#
# Processing distrito: PERUS
#   - Total rows: 124
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PERUS.geojson'
#
# Processing distrito: VILA LEOPOLDINA
#   - Total rows: 65
#   - Sampled rows: 65
#   - Successfully saved sample to 'samples/VILA LEOPOLDINA.geojson'
#
# Processing distrito: PINHEIROS
#   - Total rows: 150
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PINHEIROS.geojson'
#
# Processing distrito: PARQUE DO CARMO
#   - Total rows: 79
#   - Sampled rows: 79
#   - Successfully saved sample to 'samples/PARQUE DO CARMO.geojson'
#
# Processing distrito: VILA MEDEIROS
#   - Total rows: 201
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA MEDEIROS.geojson'
#
# Processing distrito: VILA MARIA
#   - Total rows: 157
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA MARIA.geojson'
#
# Processing distrito: JAGUARE
#   - Total rows: 102
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JAGUARE.geojson'
#
# Processing distrito: CAMPO GRANDE
#   - Total rows: 152
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CAMPO GRANDE.geojson'
#
# Processing distrito: JARDIM HELENA
#   - Total rows: 200
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JARDIM HELENA.geojson'
#
# Processing distrito: ITAIM PAULISTA
#   - Total rows: 317
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ITAIM PAULISTA.geojson'
#
# Processing distrito: LAJEADO
#   - Total rows: 206
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/LAJEADO.geojson'
#
# Processing distrito: RIO PEQUENO
#   - Total rows: 241
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/RIO PEQUENO.geojson'
#
# Processing distrito: SAO LUCAS
#   - Total rows: 163
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAO LUCAS.geojson'
#
# Processing distrito: PARELHEIROS
#   - Total rows: 297
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PARELHEIROS.geojson'
#
# Processing distrito: SACOMA
#   - Total rows: 316
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SACOMA.geojson'
#
# Processing distrito: SAO RAFAEL
#   - Total rows: 185
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAO RAFAEL.geojson'
#
# Processing distrito: VILA PRUDENTE
#   - Total rows: 137
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA PRUDENTE.geojson'
#
# Processing distrito: VILA CURUCA
#   - Total rows: 176
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA CURUCA.geojson'
#
# Processing distrito: SAPOPEMBA
#   - Total rows: 340
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAPOPEMBA.geojson'
#
# Processing distrito: IPIRANGA
#   - Total rows: 140
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/IPIRANGA.geojson'
#
# Processing distrito: MANDAQUI
#   - Total rows: 159
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/MANDAQUI.geojson'
#
# Processing distrito: VILA ANDRADE
#   - Total rows: 204
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA ANDRADE.geojson'
#
# Processing distrito: BRAS
#   - Total rows: 41
#   - Sampled rows: 41
#   - Successfully saved sample to 'samples/BRAS.geojson'
#
# Processing distrito: JABAQUARA
#   - Total rows: 370
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JABAQUARA.geojson'
#
# Processing distrito: CIDADE ADEMAR
#   - Total rows: 343
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CIDADE ADEMAR.geojson'
#
# Processing distrito: PEDREIRA
#   - Total rows: 228
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PEDREIRA.geojson'
#
# Processing distrito: SANTO AMARO
#   - Total rows: 123
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SANTO AMARO.geojson'
#
# Processing distrito: PENHA
#   - Total rows: 167
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PENHA.geojson'
#
# Processing distrito: REPUBLICA
#   - Total rows: 138
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/REPUBLICA.geojson'
#
# Processing distrito: SAO MATEUS
#   - Total rows: 198
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAO MATEUS.geojson'
#
# Processing distrito: GRAJAU
#   - Total rows: 655
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/GRAJAU.geojson'
#
# Processing distrito: SANTA CECILIA
#   - Total rows: 146
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SANTA CECILIA.geojson'
#
# Processing distrito: MARSILAC
#   - Total rows: 51
#   - Sampled rows: 51
#   - Successfully saved sample to 'samples/MARSILAC.geojson'
#
# Processing distrito: ARICANDUVA
#   - Total rows: 105
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ARICANDUVA.geojson'
#
# Processing distrito: VILA SONIA
#   - Total rows: 236
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA SONIA.geojson'
#
# Processing distrito: CURSINO
#   - Total rows: 149
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CURSINO.geojson'
#
# Processing distrito: CONSOLACAO
#   - Total rows: 121
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CONSOLACAO.geojson'
#
# Processing distrito: SAO MIGUEL
#   - Total rows: 112
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAO MIGUEL.geojson'
#
# Processing distrito: JARAGUA
#   - Total rows: 253
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JARAGUA.geojson'
#
# Processing distrito: ANHANGUERA
#   - Total rows: 101
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ANHANGUERA.geojson'
#
# Processing distrito: JAGUARA
#   - Total rows: 18
#   - Sampled rows: 18
#   - Successfully saved sample to 'samples/JAGUARA.geojson'
#
# Processing distrito: VILA FORMOSA
#   - Total rows: 101
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA FORMOSA.geojson'
#
# Processing distrito: CANGAIBA
#   - Total rows: 175
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CANGAIBA.geojson'
#
# Processing distrito: AGUA RASA
#   - Total rows: 110
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/AGUA RASA.geojson'
#
# Processing distrito: TREMEMBE
#   - Total rows: 302
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/TREMEMBE.geojson'
#
# Processing distrito: BRASILANDIA
#   - Total rows: 348
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/BRASILANDIA.geojson'
#
# Processing distrito: CACHOEIRINHA
#   - Total rows: 205
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CACHOEIRINHA.geojson'
#
# Processing distrito: SANTANA
#   - Total rows: 203
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SANTANA.geojson'
#
# Processing distrito: GUAIANASES
#   - Total rows: 147
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/GUAIANASES.geojson'
#
# Processing distrito: BUTANTA
#   - Total rows: 122
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/BUTANTA.geojson'
#
# Processing distrito: CARRAO
#   - Total rows: 101
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CARRAO.geojson'
#
# Processing distrito: IGUATEMI
#   - Total rows: 180
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/IGUATEMI.geojson'
#
# Processing distrito: MOEMA
#   - Total rows: 143
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/MOEMA.geojson'
#
# Processing distrito: PERDIZES
#   - Total rows: 209
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PERDIZES.geojson'
#
# Processing distrito: LAPA
#   - Total rows: 122
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/LAPA.geojson'
#
# Processing distrito: CAPAO REDONDO
#   - Total rows: 367
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CAPAO REDONDO.geojson'
#
# Processing distrito: SAUDE
#   - Total rows: 200
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/SAUDE.geojson'
#
# Processing distrito: CAMPO BELO
#   - Total rows: 122
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CAMPO BELO.geojson'
#
# Processing distrito: CAMPO LIMPO
#   - Total rows: 302
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CAMPO LIMPO.geojson'
#
# Processing distrito: JARDIM SAO LUIS
#   - Total rows: 359
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JARDIM SAO LUIS.geojson'
#
# Processing distrito: SAO DOMINGOS
#   - Total rows: 93
#   - Sampled rows: 93
#   - Successfully saved sample to 'samples/SAO DOMINGOS.geojson'
#
# Processing distrito: TATUAPE
#   - Total rows: 166
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/TATUAPE.geojson'
#
# Processing distrito: JOSE BONIFACIO
#   - Total rows: 192
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JOSE BONIFACIO.geojson'
#
# Processing distrito: FREGUESIA DO O
#   - Total rows: 201
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/FREGUESIA DO O.geojson'
#
# Processing distrito: TUCURUVI
#   - Total rows: 148
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/TUCURUVI.geojson'
#
# Processing distrito: BELEM
#   - Total rows: 54
#   - Sampled rows: 54
#   - Successfully saved sample to 'samples/BELEM.geojson'
#
# Processing distrito: JARDIM PAULISTA
#   - Total rows: 195
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/JARDIM PAULISTA.geojson'
#
# Processing distrito: MOOCA
#   - Total rows: 123
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/MOOCA.geojson'
#
# Processing distrito: VILA MARIANA
#   - Total rows: 218
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/VILA MARIANA.geojson'
#
# Processing distrito: CIDADE DUTRA
#   - Total rows: 229
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CIDADE DUTRA.geojson'
#
# Processing distrito: BELA VISTA
#   - Total rows: 115
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/BELA VISTA.geojson'
#
# Processing distrito: ALTO DE PINHEIROS
#   - Total rows: 55
#   - Sampled rows: 55
#   - Successfully saved sample to 'samples/ALTO DE PINHEIROS.geojson'
#
# Processing distrito: ITAIM BIBI
#   - Total rows: 184
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/ITAIM BIBI.geojson'
#
# Processing distrito: CAMBUCI
#   - Total rows: 36
#   - Sampled rows: 36
#   - Successfully saved sample to 'samples/CAMBUCI.geojson'
#
# Processing distrito: LIBERDADE
#   - Total rows: 100
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/LIBERDADE.geojson'
#
# Processing distrito: SOCORRO
#   - Total rows: 44
#   - Sampled rows: 44
#   - Successfully saved sample to 'samples/SOCORRO.geojson'
#
# Processing distrito: MORUMBI
#   - Total rows: 120
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/MORUMBI.geojson'
#
# Processing distrito: BARRA FUNDA
#   - Total rows: 21
#   - Sampled rows: 21
#   - Successfully saved sample to 'samples/BARRA FUNDA.geojson'
#
# Processing distrito: LIMAO
#   - Total rows: 112
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/LIMAO.geojson'
#
# Processing distrito: PIRITUBA
#   - Total rows: 236
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/PIRITUBA.geojson'
#
# Processing distrito: CASA VERDE
#   - Total rows: 119
#   - Sampled rows: 100
#   - Successfully saved sample to 'samples/CASA VERDE.geojson'
#
# Processing distrito: VILA GUILHERME
#   - Total rows: 69
#   - Sampled rows: 69
#   - Successfully saved sample to 'samples/VILA GUILHERME.geojson'
#
# Processing distrito: SE
#   - Total rows: 39
#   - Sampled rows: 39
#   - Successfully saved sample to 'samples/SE.geojson'
#
# Processing distrito: PARI
#   - Total rows: 17
#   - Sampled rows: 17
#   - Successfully saved sample to 'samples/PARI.geojson'
#
# Processing distrito: BOM RETIRO
#   - Total rows: 34
#   - Sampled rows: 34
#   - Successfully saved sample to 'samples/BOM RETIRO.geojson'
#
# --- Random sampling process completed ---
# Total samples = 8816
